# %% [markdown]
# # Introducción a la sintaxis básica de Python
#
# Este material práctico presenta la **sintaxis básica de Python**, necesaria para trabajar con datos climáticos y ambientales.
#
# En este cuaderno se tratarán los siguientes temas:
#
# - Operaciones aritméticas (+, -, *, /, etc.)
# - Tipos de datos y variables
# - Listas (list)
# - Diccionarios (dict)
# - Booleanos (bool) y operaciones de comparación
# - Condicionales if
# - Bucles for
# - Definición y uso de funciones
# - Conceptos básicos de pip y PyPI
#
# Cada sección incluye una breve explicación teórica junto con ejemplos de código que los participantes pueden ejecutar directamente.
# El objetivo es comprender la estructura fundamental del lenguaje antes de abordar datos climáticos y ambientales.
#
# ### ¿Qué es Python?
# - Es un lenguaje de programación de propósito general utilizado en análisis de datos, investigación científica, desarrollo web, automatización y muchos otros campos.
# - Su sintaxis es simple e intuitiva, y dispone de numerosas bibliotecas, por lo que es adecuado incluso para principiantes.
#
# ### ¿Qué es Jupyter Notebook?
# - Es un entorno interactivo que permite escribir código y explicaciones en el mismo documento.
# - Es especialmente útil para la enseñanza, ya que permite ejecutar el código línea por línea.
#
# ### Cómo ejecutar una celda
# - En una celda de código, presione **Shift + Enter** para ejecutarla.
# - Las celdas Markdown se utilizan para escribir explicaciones y texto descriptivo.

# %%
# Primer ejemplo de ejecución en Python
print("¡Hola, Python!")
# Out:
# ¡Hola, Python!

# %% [markdown]
# ## 🎯 Quiz — Cambia la frase y muéstrala en pantalla
#
# Modifica el código anterior para imprimir **tu propio nombre**.

# %% [markdown]
# # Operaciones aritméticas básicas
#
# Python se puede usar como una calculadora.
# Las operaciones básicas son las siguientes:
#
# - `+` suma
# - `-` resta
# - `*` multiplicación
# - `/` división
# - `**` potenciación
# - `%` módulo (resto)
#
# Es una buena práctica usar paréntesis para dejar clara la prioridad de las operaciones.

# %%
a = 10
b = 3

print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a ** b =", a ** b)
print("a % b =", a % b)
# Out:
# a + b = 13
# a - b = 7
# a * b = 30
# a / b = 3.3333333333333335
# a ** b = 1000
# a % b = 1

# %% [markdown]
# # Tipos de datos y variables
#
# Los tipos de datos en Python son la unidad básica para representar información.
# Los principiantes deben conocer los siguientes tipos fundamentales:
#
# - Entero (int): 5, 20, -3
# - Número decimal (float): 3.14, 0.98, -12.5
# - Cadena de texto (str): "Santo Domingo", "Ministerio de Medio Ambiente", "temperatura"
# - Booleano (bool): True, False
#
# Los tipos de datos son muy importantes al trabajar con información ambiental.
# Por ejemplo, la temperatura (°C) se expresa como un número decimal,
# el nombre del punto de observación como una cadena de texto
# y la verificación de si supera un umbral como un valor booleano.
#
# Una variable es una “etiqueta” que almacena un valor.
# En Python se crea utilizando el signo `=`.

# %%
# Ejemplo de valores observados
temperature = 28.5        # Temperatura (°C)
station_name = "Santo Domingo"  # Nombre del punto de observación
rainfall = 12             # Precipitación (mm)
is_protected_area = True  # Zona protegida (sí/no)

print(type(temperature), temperature)
print(type(station_name), station_name)
print(type(rainfall), rainfall)
print(type(is_protected_area), is_protected_area)
# Out:
# <class 'float'> 28.5
# <class 'str'> Santo Domingo
# <class 'int'> 12
# <class 'bool'> True

# %% [markdown]
# # Listas (list)
#
# Una lista es un tipo de dato que permite almacenar varios valores al mismo tiempo.
# Es muy útil para manejar información de monitoreo ambiental, como “valores medidos en varios puntos”.
#
# Ejemplos:
# - Lista de temperaturas de diferentes regiones
# - Lista de precipitaciones por hora durante un día
# - Lista de valores de pH en varios sitios de muestreo
#
# Características de las listas:
# - Se utilizan corchetes [ ].
# - Los valores tienen un orden (el índice comienza en 0).
# - La longitud se verifica con la función len().

# %%
# Temperaturas del aire en varias regiones (°C)
temperatures = [28.5, 29.1, 30.0, 27.8]

# Verificar el primer valor
print("Primera temperatura:", temperatures[0])

# Agregar un valor a la lista
temperatures.append(29.4)

# Longitud total
print("Longitud de la lista:", len(temperatures))

# Imprimir todos los valores
print("Lista completa:", temperatures)
# Out:
# Primera temperatura: 28.5
# Longitud de la lista: 5
# Lista completa: [28.5, 29.1, 30.0, 27.8, 29.4]

# %% [markdown]
# ## 🎯 Quiz — Calcula e imprime la temperatura promedio de la lista.

# %% [markdown]
# # Diccionarios (dict)
#
# Un diccionario es un tipo de dato que almacena información en formato “clave: valor”.
# Es especialmente útil para representar información de puntos de observación en datos ambientales.
#
# Ejemplos:
# - {"estación": "Santo Domingo", "temperatura": 28.5, "humedad": 72}
# - {"especie": "golondrina dorada", "individuos": 12, "protegida": True}
#
# Los diccionarios utilizan llaves { } y los valores se obtienen mediante sus claves (keys).

# %%
# Información del punto de observación ambiental
station = {
    "name": "Santo Domingo",
    "temperature": 28.5,
    "humidity": 72,
    "protected_area": True
}

print(station["name"])
print(station["temperature"])
print(station["protected_area"])
# Out:
# Santo Domingo
# 28.5
# True

# %% [markdown]
# ## 🎯 Quiz — Escribe un código que imprima el valor de la humedad (humidity) del diccionario anterior.

# %% [markdown]
# # Booleanos (bool) y operadores de comparación
#
# El tipo booleano (bool) tiene dos valores posibles: **True** (verdadero) y **False** (falso).
#
# En los datos ambientales, este tipo de comparación aparece con mucha frecuencia:
# - ¿La temperatura es mayor que el valor de referencia?
# - ¿El nivel de contaminación supera el límite permitido?
# - ¿La precipitación es mayor que 0?
#
# Operadores de comparación:
# - `==` igual a
# - `!=` diferente de
# - `>` mayor que
# - `<` menor que
# - `>=` mayor o igual que
# - `<=` menor o igual que

# %%
temperature = 32
threshold = 30

print("¿Supera el valor de referencia?:", temperature > threshold)
print("¿Es el mismo valor?:", temperature == threshold)
print("¿Es más bajo?:", temperature < threshold)
# Out:
# ¿Supera el valor de referencia?: True
# ¿Es el mismo valor?: False
# ¿Es más bajo?: False

# %% [markdown]
# # Condicionales if
#
# Las sentencias condicionales permiten que el programa actúe de manera diferente según una condición.
#
# Ejemplos comunes en el trabajo ambiental:
# - Si la temperatura es igual o superior a 30°C → “Alerta de alta temperatura”
# - Si el índice de contaminación del aire supera el valor límite → “Advertencia”
# - Aplicar un procedimiento diferente según si el área es protegida o no
#
# Estructura básica:
# ```
# if condición:
#     instrucción
# elif condición:
#     instrucción
# else:
#     instrucción
# ```

# %%
pm25 = 42  # Concentración de PM2.5 en el aire (µg/m³)

if pm25 > 50:
    print("Calidad del aire: Mala (se requiere precaución)")
elif pm25 > 25:
    print("Calidad del aire: Moderada")
else:
    print("Calidad del aire: Buena")
# Out:
# Calidad del aire: Moderada

# %% [markdown]
# # Bucles for
#
# Los bucles **for** permiten recorrer listas u otros conjuntos de datos y procesar cada valor uno por uno.
#
# Se utilizan con mucha frecuencia en el análisis de datos ambientales.
# Por ejemplo:
# - Imprimir la temperatura de varios puntos de observación
# - Recorrer los datos de precipitación de los 365 días del año
# - Procesar la cantidad de individuos de varias especies

# %%
temperatures = [28.5, 29.1, 30.0, 27.8]

for t in temperatures:
    print("Temperatura medida:", t)
# Out:
# Temperatura medida: 28.5
# Temperatura medida: 29.1
# Temperatura medida: 30.0
# Temperatura medida: 27.8

# %% [markdown]
# # Funciones (Function)
#
# Una función permite agrupar código que se repite varias veces y asignarle un nombre para poder reutilizarlo fácilmente.
#
# En el análisis de datos ambientales, las funciones son útiles para automatizar tareas como:
# - Evaluar si la temperatura supera un umbral
# - Calcular la categoría de calidad del aire
# - Convertir unidades de medida

# %%
def check_temp(temp):
    if temp >= 30:
        return "Alta temperatura"
    else:
        return "Normal"

print(check_temp(28))
print(check_temp(32))
# Out:
# Normal
# Alta temperatura

# %% [markdown]
# # pip y PyPI
#
# Python cuenta con una gran variedad de bibliotecas externas.
# En el análisis de datos ambientales se utilizan con frecuencia paquetes como `pandas`, `geopandas`, `matplotlib`, entre otros.
#
# ## Guía de instalación de Python
#
# Para instalar Python, descárguelo desde el sitio oficial:
#
# - Sitio web oficial de Python: https://www.python.org/downloads/
#
# Durante la instalación, marque la opción **“Add Python to PATH”** para facilitar el uso de pip.
#
# ## Instalación de Jupyter Notebook
#
# Después de instalar Python, puede instalar Jupyter Notebook desde la terminal o símbolo del sistema con el siguiente comando:
#
# ```
# pip install notebook
# ```
#
# ## ¿Qué es pip?
#
# `pip` es la herramienta para instalar paquetes de Python.
# Permite descargar e instalar automáticamente los paquetes desde PyPI.
#
# Ejemplos:
# ```
# pip install pandas
# pip install geopandas
# ```
#
# ## ¿Qué es PyPI?
#
# **PyPI (Python Package Index)** es el repositorio central donde se almacenan los paquetes creados por desarrolladores de todo el mundo.
#
# - Sitio oficial de PyPI: https://pypi.org/
#
# pip descarga los paquetes directamente desde PyPI.
#
# En resumen:
#
# - **pip = herramienta para instalar paquetes de Python**
# - **PyPI = repositorio donde se almacenan los paquetes de Python**
#
# En esta sección hemos visto el flujo básico: instalación de Python → instalación de Jupyter → uso de pip y PyPI.
# A partir de aquí podrá instalar paquetes como pandas, geopandas y leafmap para analizar datos ambientales.
