# %% [markdown]
# # GBIF 종 출현 자료 기반 공간 히트맵 분석 실습
#
# GBIF(Global Biodiversity Information Facility)에서 특정 종의 출현 데이터를 불러와 간단한 빙식의 시각화를 수행하는 실습 예제입니다.
#
# 주요 내용은 다음과 같습니다.
#
# - GBIF API를 이용한 종 출현 데이터 수집
# - GeoPandas를 활용한 GeoDataFrame 생성 및 GPKG 저장
# - matplotlib을 이용한 산점도 작성
# - leafmap을 활용한 인터랙티브 히트맵 시각화
#
# 예제 종으로는 도미니카공화국(DO)에서 관찰된 **황금제비(*Tachycineta euchrysea*)**를 사용합니다.
# 다른 종으로 쉽게 교체할 수 있으며, GBIF API 호출 함수를 사용해 가능한 모든 좌표 데이터를 수집한 뒤 공간 패턴을 분석할 수 있습니다.

# %%
import requests
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import leafmap.foliumap as leafmap

from shapely.geometry import Point

# %% [markdown]
# ## GBIF API 함수 정의

# %%
def get_gbif_species_data(species_name, country_code, max_records=5000):
    base_url = "https://api.gbif.org/v1/occurrence/search"
    limit = 300
    offset = 0
    all_results = []
    total_available = None

    while True:
        params = {
            "scientificName": species_name,
            "country": country_code,
            "hasCoordinate": "true",
            "basisOfRecord": "HUMAN_OBSERVATION",
            "limit": limit,
            "offset": offset,
        }

        r = requests.get(base_url, params=params)
        r.raise_for_status()
        data = r.json()

        if total_available is None:
            total_available = data.get("count", None)
            print(f"[INFO] GBIF total count = {total_available}")

        results = data.get("results", [])
        if not results:
            break

        all_results.extend(results)

        if len(all_results) >= max_records:
            break
        if len(results) < limit:
            break

        offset += limit

    print(f"[INFO] 최종 수집 레코드 수 = {len(all_results)}")

    return pd.json_normalize(all_results) if all_results else pd.DataFrame()

# %% [markdown]
# ## 특정 종(황금제비) 출현 데이터 조회
#
# - 학명(`species_name`)과 국가 코드(`country_code`)를 설정
# - 앞서 정의한 함수로 GBIF 데이터를 가져와 `df_raw`에 저장

# %%
# 황금제비 학명과 도미니카공화국 국가 코드
species_name = "Tachycineta euchrysea"
country_code = "DO"  # Dominican Republic

# GBIF에서 데이터 가져오기
df_raw = get_gbif_species_data(species_name, country_code)
# Out:
# [INFO] GBIF total count = 1451
# [INFO] 최종 수집 레코드 수 = 1451

# %% [markdown]
# ## GPKG 파일로 저장
#
# GeoDataFrame을 GeoPackage 파일(`.gpkg`)로 저장하는 함수를 정의하고 실제 파일로 저장합니다.

# %%
# GBIF → GeoDataFrame 변환
gdf = gpd.GeoDataFrame(
    df_raw,
    geometry=gpd.points_from_xy(
        df_raw["decimalLongitude"],
        df_raw["decimalLatitude"]
    ),
    crs="EPSG:4326"
)

# GPKG 저장 함수
def save_gpkg(gdf, out_file):
    gdf.to_file(out_file, driver="GPKG")
    print(f"[INFO] GPKG 저장 완료: {out_file}")

# 저장 파일명
out_file = "gbif_tachycineta_euchrysea.gpkg"

# 함수 호출
save_gpkg(gdf, out_file)
# Out:
# [INFO] GPKG 저장 완료: gbif_tachycineta_euchrysea.gpkg

# %%
# 다시 읽기
gdf = gpd.read_file(out_file)

# head 확인
gdf.head()
# Out:
#           key                            datasetKey  \
# 0  5313210987  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1  5316763961  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 2  5365862328  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 3  5385270029  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 4  5388599924  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
#
#                        publishingOrgKey                       installationKey  \
# 0  e2e717bf-551a-4917-bdc9-4fa0f342c530  7182d304-b0a2-404b-baba-2086a325c221
# 1  e2e717bf-551a-4917-bdc9-4fa0f342c530  7182d304-b0a2-404b-baba-2086a325c221
# 2  e2e717bf-551a-4917-bdc9-4fa0f342c530  7182d304-b0a2-404b-baba-2086a325c221
# 3  e2e717bf-551a-4917-bdc9-4fa0f342c530  7182d304-b0a2-404b-baba-2086a325c221
# 4  e2e717bf-551a-4917-bdc9-4fa0f342c530  7182d304-b0a2-404b-baba-2086a325c221
#
#                  hostingOrganizationKey publishingCountry     protocol  \
# 0  e2e717bf-551a-4917-bdc9-4fa0f342c530                DO  DWC_ARCHIVE
# 1  e2e717bf-551a-4917-bdc9-4fa0f342c530                DO  DWC_ARCHIVE
# 2  e2e717bf-551a-4917-bdc9-4fa0f342c530                DO  DWC_ARCHIVE
# 3  e2e717bf-551a-4917-bdc9-4fa0f342c530                DO  DWC_ARCHIVE
# 4  e2e717bf-551a-4917-bdc9-4fa0f342c530                DO  DWC_ARCHIVE
#
#                      lastCrawled                     lastParsed  crawlId  ...  \
# 0  2025-10-29T11:02:38.172+00:00  2025-11-05T07:38:23.004+00:00       24  ...
# 1  2025-10-29T11:02:38.172+00:00  2025-11-05T07:40:40.373+00:00       24  ...
# 2  2025-10-29T11:02:38.172+00:00  2025-11-05T07:46:00.626+00:00       24  ...
# 3  2025-10-29T11:02:38.172+00:00  2025-11-05T07:42:24.171+00:00       24  ...
# 4  2025-10-29T11:02:38.172+00:00  2025-11-05T07:39:02.891+00:00       24  ...
#
#   nomenclaturalCode  fieldNotes verbatimElevation  behavior  \
# 0              None        None              None      None
# 1              None        None              None      None
# 2              None        None              None      None
# 3              None        None              None      None
# 4              None        None              None      None
#
#    higherClassification  extensions.http://rs.tdwg.org/ac/terms/Multimedia  \
# 0                  None                                               None
# 1                  None                                               None
# 2                  None                                               None
# 3                  None                                               None
# 4                  None                                               None
#
#    occurrenceRemarks  associatedTaxa  distanceFromCentroidInMeters  \
# 0               None            None                           NaN
# 1               None            None                           NaN
# 2               None            None                           NaN
# 3               None            None                           NaN
# 4               None            None                           NaN
#
#                      geometry
# 0  POINT (-71.69899 18.30019)
# 1  POINT (-71.69899 18.30019)
# 2   POINT (-71.6988 18.30823)
# 3  POINT (-71.69899 18.30019)
# 4  POINT (-71.70744 18.31246)
#
# [5 rows x 158 columns]

# %% [markdown]
# ## 산점도 시각화
#
# GeoDataFrame에서 경·위도(lon, lat)를 추출하여 matplotlib 산점도(Scatter plot)로 공간 분포를 확인합니다.

# %%
# geometry에서 lon/lat 추출
gdf["lon"] = gdf.geometry.x
gdf["lat"] = gdf.geometry.y

plt.figure(figsize=(5, 5))
plt.scatter(gdf["lon"], gdf["lat"], alpha=0.4, s=10)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Golden Swallow in Dominican Republic")
plt.grid(True)
plt.show()

# %% [markdown]
# ## leafmap 기반 인터랙티브 Heatmap 생성
#
# leafmap은 folium 또는 ipyleaflet 기반의 지도 위젯을 제공하며 CSV 파일 기반으로 히트맵을 그릴 수 있습니다.

# %%
m = leafmap.Map(width="700px", height="400px")
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6099768297fa7f13e59355bedba577b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6099768297fa7f13e59355bedba577b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6099768297fa7f13e59355bedba577b9 = L.map(
#                 &quot;map_6099768297fa7f13e59355bedba577b9&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_6099768297fa7f13e59355bedba577b9);
#
#
#
#
#
#             var tile_layer_78a8649f503735201656d845697a8068 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78a8649f503735201656d845697a8068.addTo(map_6099768297fa7f13e59355bedba577b9);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_6099768297fa7f13e59355bedba577b9);
#
#
#             map_6099768297fa7f13e59355bedba577b9.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var layer_control_e5d70a4a2451424d38f3b8371e28d63b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_78a8649f503735201656d845697a8068,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_e5d70a4a2451424d38f3b8371e28d63b = L.control.layers(
#                 layer_control_e5d70a4a2451424d38f3b8371e28d63b_layers.base_layers,
#                 layer_control_e5d70a4a2451424d38f3b8371e28d63b_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_6099768297fa7f13e59355bedba577b9);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700.0" height="400.0"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
m = leafmap.Map(width="700px", height="400px")
m.add_basemap("HYBRID")
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cea0cdd6887cf34c8f9e18177614475 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cea0cdd6887cf34c8f9e18177614475&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cea0cdd6887cf34c8f9e18177614475 = L.map(
#                 &quot;map_4cea0cdd6887cf34c8f9e18177614475&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4cea0cdd6887cf34c8f9e18177614475);
#
#
#
#
#
#             var tile_layer_3097e5c88a6961b83e67db7b93c6b606 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3097e5c88a6961b83e67db7b93c6b606.addTo(map_4cea0cdd6887cf34c8f9e18177614475);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_4cea0cdd6887cf34c8f9e18177614475);
#
#
#             map_4cea0cdd6887cf34c8f9e18177614475.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_804020d2994dd1e1abbe57361098404a = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Esri&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_804020d2994dd1e1abbe57361098404a.addTo(map_4cea0cdd6887cf34c8f9e18177614475);
#
#
#             var layer_control_e54225359715a595c2ee7c8d9b28af41_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3097e5c88a6961b83e67db7b93c6b606,
#                 },
#                 overlays :  {
#                     &quot;Esri.WorldImagery&quot; : tile_layer_804020d2994dd1e1abbe57361098404a,
#                 },
#             };
#             let layer_control_e54225359715a595c2ee7c8d9b28af41 = L.control.layers(
#                 layer_control_e54225359715a595c2ee7c8d9b28af41_layers.base_layers,
#                 layer_control_e54225359715a595c2ee7c8d9b28af41_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_4cea0cdd6887cf34c8f9e18177614475);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700.0" height="400.0"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
m = leafmap.Map(width="700px", height="400px")
m.add_tile_layer(
    url="https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}",
    name="Google Satellite",
    attribution="Google",
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09fa007f9d421aa8c1a596cad0ced76e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09fa007f9d421aa8c1a596cad0ced76e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09fa007f9d421aa8c1a596cad0ced76e = L.map(
#                 &quot;map_09fa007f9d421aa8c1a596cad0ced76e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_09fa007f9d421aa8c1a596cad0ced76e);
#
#
#
#
#
#             var tile_layer_b28f5ad6b48ab5a07a39a8e0b5969944 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b28f5ad6b48ab5a07a39a8e0b5969944.addTo(map_09fa007f9d421aa8c1a596cad0ced76e);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_09fa007f9d421aa8c1a596cad0ced76e);
#
#
#             map_09fa007f9d421aa8c1a596cad0ced76e.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_87143d04f86692f32d0e420334d01496 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_87143d04f86692f32d0e420334d01496.addTo(map_09fa007f9d421aa8c1a596cad0ced76e);
#
#
#             var layer_control_1ecea481d7f0d6cd012177a93716bb3c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b28f5ad6b48ab5a07a39a8e0b5969944,
#                 },
#                 overlays :  {
#                     &quot;Google Satellite&quot; : tile_layer_87143d04f86692f32d0e420334d01496,
#                 },
#             };
#             let layer_control_1ecea481d7f0d6cd012177a93716bb3c = L.control.layers(
#                 layer_control_1ecea481d7f0d6cd012177a93716bb3c_layers.base_layers,
#                 layer_control_1ecea481d7f0d6cd012177a93716bb3c_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_09fa007f9d421aa8c1a596cad0ced76e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700.0" height="400.0"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# leafmap.add_heatmap용 CSV 저장
filepath = "golden_swallow_do_heatmap.csv"
gdf["lon"] = gdf.geometry.x
gdf["lat"] = gdf.geometry.y
gdf["weight"] = 1
gdf[["lat", "lon", "weight"]].to_csv(filepath, index=False)

# 지도 중심은 관측치 평균 위치로
center_lon = gdf["lon"].mean()
center_lat = gdf["lat"].mean()

# leafmap 히트맵
m = leafmap.Map(width="700px", height="400px", center=[center_lat, center_lon], zoom=7)
m.add_heatmap(
    filepath,
    latitude="lat",
    longitude="lon",
    value="weight",
    name="Golden Swallow heat map",
    radius=20,
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5819d1da9dd4f06b9fb3a66793a6b416 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5819d1da9dd4f06b9fb3a66793a6b416&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5819d1da9dd4f06b9fb3a66793a6b416 = L.map(
#                 &quot;map_5819d1da9dd4f06b9fb3a66793a6b416&quot;,
#                 {
#                     center: [18.34151817229497, -71.49189902756719],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5819d1da9dd4f06b9fb3a66793a6b416);
#
#
#
#
#
#             var tile_layer_ef5899c539273728a103865dde1ee080 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef5899c539273728a103865dde1ee080.addTo(map_5819d1da9dd4f06b9fb3a66793a6b416);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_5819d1da9dd4f06b9fb3a66793a6b416);
#
#
#             map_5819d1da9dd4f06b9fb3a66793a6b416.fitBounds(
#                 [[18.34151817229497, -71.49189902756719], [18.34151817229497, -71.49189902756719]],
#                 {&quot;maxZoom&quot;: 7}
#             );
#
#
#             var feature_group_f37fe1d1a967dfa141104ca52f3c2b97 = L.featureGroup(
#                 {
# }
#             );
#
#
#             